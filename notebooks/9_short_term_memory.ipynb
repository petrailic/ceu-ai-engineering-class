# %% [markdown]
# # Short-Term Memory

# %%
from agents import Agent, Runner, SQLiteSession, trace
from setup import bedrock_tool
# Out:
# ✅ AWS credentials found
# ✅ OpenAI credentials found
# ✅ EXA credentials found

# %%
nutrition_agent = Agent(
    name="Nutrition Assistant",
    instructions="""
    You are a helpful assistant comparing how healthy different foods are.
    If you answer, give a list of how healthy the foods are with a score from 1 to 10. Order by: healtiest food comes first.

    Example:
    Q: Compare X and Y
    A: X is healtier as Y.
    1) X: 8/10 - Very healthy but high in fructose
    2) Y: 3/10 - High in sugar and fat
    """,
    model="litellm/bedrock/eu.amazon.nova-lite-v1:0",
)

# %% [markdown]
# ## No Memory

# %%
with trace("Compare without Memory") as t:
    result = await Runner.run(nutrition_agent, "Which is healthier, bananas or lollipop?")

print(f"Output: {result.final_output}")
print(f"\nTrace URL: https://platform.openai.com/logs/trace?trace_id={t.trace_id}")
# Out:
# Output: Sure, here is a comparison of the healthiness of bananas and lollipops:
#
# 1) **Bananas: 9/10 - Very healthy**
#     - **Nutritional Benefits:** High in potassium, vitamin B6, vitamin C, fiber, and antioxidants.
#     - **Cons:** Moderate calories and natural sugars, but beneficial for overall health.
#
# 2) **Lollipop: 1/10 - Not healthy**
#     - **Nutritional Benefits:** None.
#     - **Cons:** High in refined sugars, artificial colors, flavors, and provides empty calories with no nutritional benefits.
#
# Based on this comparison, bananas are significantly healthier than lollipops.
#
# Trace URL: https://platform.openai.com/logs/trace?trace_id=trace_f0409ab992dc412781aec4754269fe69

# %%
with trace("Add Apple - without Memory") as t:
    result = await Runner.run(nutrition_agent, "Add apples to the comparison")

print(f"Output: {result.final_output}")
print(f"\nTrace URL: https://platform.openai.com/logs/trace?trace_id={t.trace_id}")
# Out:
# Output: Sure, let's compare apples to two other foods: broccoli and ice cream.
#
# Q: Compare apples, broccoli, and ice cream.
#
# A:
# 1) Broccoli: 10/10 - Very healthy, rich in vitamins, minerals, and antioxidants.
# 2) Apples: 8/10 - Very healthy, high in fiber, vitamins, and antioxidants.
# 3) Ice cream: 2/10 - High in sugar and fat, low in essential nutrients.
#
# Trace URL: https://platform.openai.com/logs/trace?trace_id=trace_35a49ce42f734a6480f49d7fa32d1dc0

# %% [markdown]
# ## Short Term Memory

# %%
session = SQLiteSession("conversation_history")

# %%
result = await Runner.run(
    nutrition_agent, "Which is healthier, bananas or lollipop?", session=session
)
print(result.final_output)
# Out:
# Here's a comparison of the healthiness of bananas and lollipops, scored from 1 to 10:
#
# 1) Bananas: 9/10 - Bananas are very healthy. They are rich in essential nutrients like potassium, vitamin B6, and dietary fiber. They also provide natural sugars and antioxidants, making them a great energy source and beneficial for heart health and digestion.
#
# 2) Lollipops: 1/10 - Lollipops are highly unhealthy. They are primarily composed of refined sugars and artificial additives with little to no nutritional value. Consuming lollipops can lead to spikes in blood sugar levels, contribute to weight gain, and increase the risk of dental problems.
#
# So, bananas are significantly healthier than lollipops.

# %%
with trace("Compare with Memory") as t:
    result = await Runner.run(
        nutrition_agent, "Add apples to the comparison", session=session
    )

print(f"Output: {result.final_output}")
print(f"\nTrace URL: https://platform.openai.com/logs/trace?trace_id={t.trace_id}")
# Out:
# Output: Here's an updated comparison of the healthiness of bananas, lollipops, and apples, scored from 1 to 10:
#
# 1) Bananas: 9/10 - Bananas are very healthy. They are rich in essential nutrients like potassium, vitamin B6, and dietary fiber. They also provide natural sugars and antioxidants, making them a great energy source and beneficial for heart health and digestion.
#
# 2) Apples: 8/10 - Apples are also very healthy. They are high in fiber, vitamin C, and various antioxidants. They can help improve heart health, aid in digestion, and provide sustained energy.
#
# 3) Lollipops: 1/10 - Lollipops are highly unhealthy. They are primarily composed of refined sugars and artificial additives with little to no nutritional value. Consuming lollipops can lead to spikes in blood sugar levels, contribute to weight gain, and increase the risk of dental problems.
#
# So, the order from healthiest to least healthy is: Bananas, Apples, Lollipops.
#
# Trace URL: https://platform.openai.com/logs/trace?trace_id=trace_211b09f7b78443b48252e5f8c59b4659
